# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
purchase_df = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(purchase_df)
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price
# 0    Extraction, Quickblade Of Trembling Hands   3.53
# 1                            Frenzied Scimitar   1.56
# 2                                 Final Critic   4.88
# 3                                  Blindscythe   3.27
# 4                                         Fury   1.44
# ..                                         ...    ...
# 775                                       Wolf   3.54
# 776                           Exiled Doomblade   1.63
# 777      Celeste, Incarnation of the Corrupted   3.46
# 778                               Final Critic   4.19
# 779                                       Dawn   4.60
#
# [780 rows x 7 columns]

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
 #Total number of players
num_players = len(purchase_data["Purchase ID"].value_counts())
num_players
# Out:
# 780

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#Number of unique items
unique_items = purchase_data["Item Name"].nunique()
unique_items
# Out:
# 179

# %%
#Average price rounded by two decimal spaces
avg_price = round(purchase_data["Price"].mean(),2)
display(avg_price)
# Out:
# 3.05

# %%
#Number of Purchases
purchase_count = purchase_data["Price"].count()
purchase_count
# Out:
# 780

# %%
#Total Revenue
purchase_total = purchase_data["Price"].sum()
purchase_total
# Out:
# 2379.77

# %%
Purchasing_Analysis_Summary_df = pd.DataFrame({
    "Number of Unique Items":[unique_items],
    "Average Price":[avg_price],
    "Number of Purchases":[purchase_count],
    "Total Revenue":[purchase_total]
    })

Purchasing_Analysis_Summary_df
# Out:
#    Number of Unique Items  Average Price  Number of Purchases  Total Revenue
# 0                     179           3.05                  780        2379.77

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
 #Gender demographics - count & percentage
gender_count = purchase_data["Gender"].value_counts()
gender_percentage = round(purchase_data["Gender"].value_counts("Male"),2)
print(gender_count)
print()
print(gender_percentage)
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64
#
# Male                     0.84
# Female                   0.14
# Other / Non-Disclosed    0.02
# Name: Gender, dtype: float64

# %%
 #Purchase count broken by gender
gender_df=pd.DataFrame({
    "Total Count":gender_count,
    "Percentage of Players":gender_percentage.map("{:,.2%}".format)
})

gender_df
# Out:
#                        Total Count Percentage of Players
# Male                           652                84.00%
# Female                         113                14.00%
# Other / Non-Disclosed           15                 2.00%

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
price_df = purchase_data[["Price", "Gender"]]
price_df
# Out:
#      Price  Gender
# 0     3.53    Male
# 1     1.56    Male
# 2     4.88    Male
# 3     3.27    Male
# 4     1.44    Male
# ..     ...     ...
# 775   3.54  Female
# 776   1.63    Male
# 777   3.46    Male
# 778   4.19    Male
# 779   4.60    Male
#
# [780 rows x 2 columns]

# %%
 #Purchase count broken by gender
gender_group = price_df.groupby(["Gender"])
gender_count = gender_group.count()
gender_count["Price"]
# Out:
# Gender
# Female                   113
# Male                     652
# Other / Non-Disclosed     15
# Name: Price, dtype: int64

# %%
 #Average purchase price broken by gender
gender_avg_price = round(gender_group.mean(),2)
gender_avg_price
# Out:
#                        Price
# Gender
# Female                  3.20
# Male                    3.02
# Other / Non-Disclosed   3.35

# %%
#Total purchases broken by gender
gender_total_price = gender_group.sum()
gender_total_price
# Out:
#                          Price
# Gender
# Female                  361.94
# Male                   1967.64
# Other / Non-Disclosed    50.19

# %%
#Average purchase total 
gender_total_avg = gender_avg_price.sum()
gender_total_avg
# Out:
# Price    9.57
# dtype: float64

# %%
average_purchase=gender_total_price/gender_count
average_purchase
# Out:
#                           Price
# Gender
# Female                 3.203009
# Male                   3.017853
# Other / Non-Disclosed  3.346000

# %%
Gender_Purchasing_Analysis_Summary_df = pd.DataFrame({
    "Purchase Count":gender_count["Price"],
    "Average Purchase":gender_avg_price["Price"],
    "Total Purchase Value":gender_total_price["Price"],
    "Average Total Purchase Per Person":average_purchase["Price"]
    })
Gender_Purchasing_Analysis_Summary_df
# Out:
#                        Purchase Count  Average Purchase  Total Purchase Value  \
# Gender
# Female                            113              3.20                361.94
# Male                              652              3.02               1967.64
# Other / Non-Disclosed              15              3.35                 50.19
#
#                        Average Total Purchase Per Person
# Gender
# Female                                          3.203009
# Male                                            3.017853
# Other / Non-Disclosed                           3.346000

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
 #Age demographic bins
age_bins = [0,10,15,20,25,30,35,40,45]
age_range = ["<10","10-14","15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

# %%
 #Displaying new bins column
purchase_data["Age Range"] = pd.cut(purchase_data["Age"], age_bins, labels=age_range, include_lowest=True)
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Range
# 0    Extraction, Quickblade Of Trembling Hands   3.53     15-19
# 1                            Frenzied Scimitar   1.56     35-39
# 2                                 Final Critic   4.88     20-24
# 3                                  Blindscythe   3.27     20-24
# 4                                         Fury   1.44     20-24
# ..                                         ...    ...       ...
# 775                                       Wolf   3.54     20-24
# 776                           Exiled Doomblade   1.63     20-24
# 777      Celeste, Incarnation of the Corrupted   3.46     15-19
# 778                               Final Critic   4.19       <10
# 779                                       Dawn   4.60     20-24
#
# [780 rows x 8 columns]

# %%
 #creates a table only displaying the prices and age ranges to make for easier viewing
age_df = purchase_data[[ "Age Range","Price"]]
age_df
# Out:
#     Age Range  Price
# 0       15-19   3.53
# 1       35-39   1.56
# 2       20-24   4.88
# 3       20-24   3.27
# 4       20-24   1.44
# ..        ...    ...
# 775     20-24   3.54
# 776     20-24   1.63
# 777     15-19   3.46
# 778       <10   4.19
# 779     20-24   4.60
#
# [780 rows x 2 columns]

# %%
#Purchase count broken by age
age_group = age_df.groupby(["Age Range"])
age_count = age_group.count()
age_count
# Out:
#            Price
# Age Range
# <10           32
# 10-14         54
# 15-19        200
# 20-24        325
# 25-29         77
# 30-34         52
# 35-39         33
# 40+            7

# %%
age_range_total = round(purchase_data["Age Range"].value_counts())
age_range_total
# Out:
# 20-24    325
# 15-19    200
# 25-29     77
# 10-14     54
# 30-34     52
# 35-39     33
# <10       32
# 40+        7
# Name: Age Range, dtype: int64

# %%
percentage_of_players=age_range_total/num_players
percentage_of_players.map("{:,.2%}".format)
# Out:
# 20-24    41.67%
# 15-19    25.64%
# 25-29     9.87%
# 10-14     6.92%
# 30-34     6.67%
# 35-39     4.23%
# <10       4.10%
# 40+       0.90%
# Name: Age Range, dtype: object

# %%
demographics_df=pd.DataFrame({
    "Total Count":age_range_total,
    "Percentage of Players":percentage_of_players.map("{:,.2%}".format)
})
demographics_df
# Out:
#        Total Count Percentage of Players
# 20-24          325                41.67%
# 15-19          200                25.64%
# 25-29           77                 9.87%
# 10-14           54                 6.92%
# 30-34           52                 6.67%
# 35-39           33                 4.23%
# <10             32                 4.10%
# 40+              7                 0.90%

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
 #creates a table only displaying the prices and age ranges to make for easier viewing
age_df
# Out:
#     Age Range  Price
# 0       15-19   3.53
# 1       35-39   1.56
# 2       20-24   4.88
# 3       20-24   3.27
# 4       20-24   1.44
# ..        ...    ...
# 775     20-24   3.54
# 776     20-24   1.63
# 777     15-19   3.46
# 778       <10   4.19
# 779     20-24   4.60
#
# [780 rows x 2 columns]

# %%
 #Purchase count broken by age
age_purchase_group = age_df.groupby(["Age Range"])
age_purchase_count = age_purchase_group.count()
age_purchase_count
# Out:
#            Price
# Age Range
# <10           32
# 10-14         54
# 15-19        200
# 20-24        325
# 25-29         77
# 30-34         52
# 35-39         33
# 40+            7

# %%
 #Average purchase price broken by age
age_avg_price = round(age_purchase_group.mean(),2)
age_avg_price
# Out:
#            Price
# Age Range
# <10         3.40
# 10-14       2.90
# 15-19       3.11
# 20-24       3.02
# 25-29       2.88
# 30-34       2.99
# 35-39       3.40
# 40+         3.08

# %%
#Total purchases broken by age
age_total_purchase = age_purchase_group.sum()
age_total_purchase
# Out:
#             Price
# Age Range
# <10        108.96
# 10-14      156.60
# 15-19      621.56
# 20-24      981.64
# 25-29      221.42
# 30-34      155.71
# 35-39      112.35
# 40+         21.53

# %%
age_avg_purchase=age_total_purchase/age_purchase_count
age_avg_purchase
# Out:
#               Price
# Age Range
# <10        3.405000
# 10-14      2.900000
# 15-19      3.107800
# 20-24      3.020431
# 25-29      2.875584
# 30-34      2.994423
# 35-39      3.404545
# 40+        3.075714

# %%
age_purchase_analysis = pd.DataFrame({"Purchase Count": age_purchase_count["Price"], "Average Purchase Price": age_avg_purchase["Price"], "Total Purchase Value": age_total_purchase["Price"], "Avg Total Purchase Per Person": age_avg_purchase["Price"]})

age_purchase_analysis
# Out:
#            Purchase Count  Average Purchase Price  Total Purchase Value  \
# Age Range
# <10                    32                3.405000                108.96
# 10-14                  54                2.900000                156.60
# 15-19                 200                3.107800                621.56
# 20-24                 325                3.020431                981.64
# 25-29                  77                2.875584                221.42
# 30-34                  52                2.994423                155.71
# 35-39                  33                3.404545                112.35
# 40+                     7                3.075714                 21.53
#
#            Avg Total Purchase Per Person
# Age Range
# <10                             3.405000
# 10-14                           2.900000
# 15-19                           3.107800
# 20-24                           3.020431
# 25-29                           2.875584
# 30-34                           2.994423
# 35-39                           3.404545
# 40+                             3.075714

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
purchase_data
# Out:
#      Purchase ID             SN  Age  Gender  Item ID  \
# 0              0        Lisim78   20    Male      108
# 1              1    Lisovynya38   40    Male      143
# 2              2     Ithergue48   24    Male       92
# 3              3  Chamassasya86   24    Male      100
# 4              4      Iskosia90   23    Male      131
# ..           ...            ...  ...     ...      ...
# 775          775     Aethedru70   21  Female       60
# 776          776         Iral74   21    Male      164
# 777          777     Yathecal72   20    Male       67
# 778          778        Sisur91    7    Male       92
# 779          779      Ennrian78   24    Male       50
#
#                                      Item Name  Price Age Range
# 0    Extraction, Quickblade Of Trembling Hands   3.53     15-19
# 1                            Frenzied Scimitar   1.56     35-39
# 2                                 Final Critic   4.88     20-24
# 3                                  Blindscythe   3.27     20-24
# 4                                         Fury   1.44     20-24
# ..                                         ...    ...       ...
# 775                                       Wolf   3.54     20-24
# 776                           Exiled Doomblade   1.63     20-24
# 777      Celeste, Incarnation of the Corrupted   3.46     15-19
# 778                               Final Critic   4.19       <10
# 779                                       Dawn   4.60     20-24
#
# [780 rows x 8 columns]

# %%
spenders_group=purchase_data.groupby("SN")

# %%
#Purchase count per customer
spender_count=spenders_group["Item ID"].count()
spender_count
# Out:
# SN
# Adairialis76     1
# Adastirin33      1
# Aeda94           1
# Aela59           1
# Aelaria33        1
#                 ..
# Yathecal82       3
# Yathedeu43       2
# Yoishirrala98    1
# Zhisrisu83       2
# Zontibe81        3
# Name: Item ID, Length: 576, dtype: int64

# %%
#Avg spender purchase
avg_spender_purchase=spenders_group["Price"].mean()
avg_spender_purchase
# Out:
# SN
# Adairialis76     2.280000
# Adastirin33      4.480000
# Aeda94           4.910000
# Aela59           4.320000
# Aelaria33        1.790000
#                    ...
# Yathecal82       2.073333
# Yathedeu43       3.010000
# Yoishirrala98    4.580000
# Zhisrisu83       3.945000
# Zontibe81        2.676667
# Name: Price, Length: 576, dtype: float64

# %%
#Total purchases per spender
total_spender_purchases=spenders_group["Price"].sum()
total_spender_purchases
# Out:
# SN
# Adairialis76     2.28
# Adastirin33      4.48
# Aeda94           4.91
# Aela59           4.32
# Aelaria33        1.79
#                  ...
# Yathecal82       6.22
# Yathedeu43       6.02
# Yoishirrala98    4.58
# Zhisrisu83       7.89
# Zontibe81        8.03
# Name: Price, Length: 576, dtype: float64

# %%
spenders_df = pd.DataFrame({"Purchase Count": spender_count, "Average Purchase Price": avg_spender_purchase, "Total Purchase Value": total_spender_purchases})
spenders_df
# Out:
#                Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Adairialis76                1                2.280000                  2.28
# Adastirin33                 1                4.480000                  4.48
# Aeda94                      1                4.910000                  4.91
# Aela59                      1                4.320000                  4.32
# Aelaria33                   1                1.790000                  1.79
# ...                       ...                     ...                   ...
# Yathecal82                  3                2.073333                  6.22
# Yathedeu43                  2                3.010000                  6.02
# Yoishirrala98               1                4.580000                  4.58
# Zhisrisu83                  2                3.945000                  7.89
# Zontibe81                   3                2.676667                  8.03
#
# [576 rows x 3 columns]

# %%
top_spenders = spenders_df.sort_values("Total Purchase Value", ascending = False)
top_spenders.head(10)
# Out:
#               Purchase Count  Average Purchase Price  Total Purchase Value
# SN
# Lisosia93                  5                3.792000                 18.96
# Idastidru52                4                3.862500                 15.45
# Chamjask73                 3                4.610000                 13.83
# Iral74                     4                3.405000                 13.62
# Iskadarya95                3                4.366667                 13.10
# Ilarin91                   3                4.233333                 12.70
# Ialallo29                  3                3.946667                 11.84
# Tyidaim51                  3                3.943333                 11.83
# Lassilsala30               3                3.836667                 11.51
# Chadolyla44                3                3.820000                 11.46

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, average item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
items_df=purchase_data[["Item ID","Item Name","Price"]]
items_df
# Out:
#      Item ID                                  Item Name  Price
# 0        108  Extraction, Quickblade Of Trembling Hands   3.53
# 1        143                          Frenzied Scimitar   1.56
# 2         92                               Final Critic   4.88
# 3        100                                Blindscythe   3.27
# 4        131                                       Fury   1.44
# ..       ...                                        ...    ...
# 775       60                                       Wolf   3.54
# 776      164                           Exiled Doomblade   1.63
# 777       67      Celeste, Incarnation of the Corrupted   3.46
# 778       92                               Final Critic   4.19
# 779       50                                       Dawn   4.60
#
# [780 rows x 3 columns]

# %%
item_group=items_df.groupby(["Item ID","Item Name"])

# %%
item_count=item_group["Item ID"].count()
item_count
# Out:
# Item ID  Item Name
# 0        Splinter                                         4
# 1        Crucifer                                         4
# 2        Verdict                                          6
# 3        Phantomlight                                     6
# 4        Bloodlord's Fetish                               5
#                                                          ..
# 178      Oathbreaker, Last Hope of the Breaking Storm    12
# 179      Wolf, Promise of the Moonwalker                  6
# 181      Reaper's Toll                                    5
# 182      Toothpick                                        3
# 183      Dragon's Greatsword                              3
# Name: Item ID, Length: 179, dtype: int64

# %%
item_purchase_total=items_df["Price"].sum
item_purchase_total
# Out:
# <bound method Series.sum of 0      3.53
# 1      1.56
# 2      4.88
# 3      3.27
# 4      1.44
#        ...
# 775    3.54
# 776    1.63
# 777    3.46
# 778    4.19
# 779    4.60
# Name: Price, Length: 780, dtype: float64>

# %%
avg_item_purchase = item_group["Price"].mean()
avg_item_purchase
# Out:
# Item ID  Item Name
# 0        Splinter                                        1.2800
# 1        Crucifer                                        2.9425
# 2        Verdict                                         2.4800
# 3        Phantomlight                                    2.4900
# 4        Bloodlord's Fetish                              1.7000
#                                                           ...
# 178      Oathbreaker, Last Hope of the Breaking Storm    4.2300
# 179      Wolf, Promise of the Moonwalker                 4.4800
# 181      Reaper's Toll                                   1.6600
# 182      Toothpick                                       4.0300
# 183      Dragon's Greatsword                             1.0900
# Name: Price, Length: 179, dtype: float64

# %%
popular_items=pd.DataFrame({"Purchase Count":item_count, "Item Price":avg_item_purchase, "Total Purchase Value":item_purchase_total})
popular_items
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 0       Splinter                                                   4
# 1       Crucifer                                                   4
# 2       Verdict                                                    6
# 3       Phantomlight                                               6
# 4       Bloodlord's Fetish                                         5
# ...                                                              ...
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 179     Wolf, Promise of the Moonwalker                            6
# 181     Reaper's Toll                                              5
# 182     Toothpick                                                  3
# 183     Dragon's Greatsword                                        3
#
#                                                       Item Price  \
# Item ID Item Name
# 0       Splinter                                          1.2800
# 1       Crucifer                                          2.9425
# 2       Verdict                                           2.4800
# 3       Phantomlight                                      2.4900
# 4       Bloodlord's Fetish                                1.7000
# ...                                                          ...
# 178     Oathbreaker, Last Hope of the Breaking Storm      4.2300
# 179     Wolf, Promise of the Moonwalker                   4.4800
# 181     Reaper's Toll                                     1.6600
# 182     Toothpick                                         4.0300
# 183     Dragon's Greatsword                               1.0900
#
#                                                                                    Total Purchase Value
# Item ID Item Name
# 0       Splinter                                      <bound method Series.sum of 0      3.53\n1    ...
# 1       Crucifer                                      <bound method Series.sum of 0      3.53\n1    ...
# 2       Verdict                                       <bound method Series.sum of 0      3.53\n1    ...
# 3       Phantomlight                                  <bound method Series.sum of 0      3.53\n1    ...
# 4       Bloodlord's Fetish                            <bound method Series.sum of 0      3.53\n1    ...
# ...                                                                                                 ...
# 178     Oathbreaker, Last Hope of the Breaking Storm  <bound method Series.sum of 0      3.53\n1    ...
# 179     Wolf, Promise of the Moonwalker               <bound method Series.sum of 0      3.53\n1    ...
# 181     Reaper's Toll                                 <bound method Series.sum of 0      3.53\n1    ...
# 182     Toothpick                                     <bound method Series.sum of 0      3.53\n1    ...
# 183     Dragon's Greatsword                           <bound method Series.sum of 0      3.53\n1    ...
#
# [179 rows x 3 columns]

# %%
most_popular_items=popular_items.sort_values("Purchase Count", ascending=False)
most_popular_items.head(10)
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 132     Persuasion                                                 9
# 108     Extraction, Quickblade Of Trembling Hands                  9
# 82      Nirvana                                                    9
# 75      Brutality Ivory Warmace                                    8
# 103     Singed Scalpel                                             8
# 34      Retribution Axe                                            8
# 37      Shadow Strike, Glory of Ending Hope                        8
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                    4.614615
# 178     Oathbreaker, Last Hope of the Breaking Storm    4.230000
# 145     Fiery Glass Crusader                            4.580000
# 132     Persuasion                                      3.221111
# 108     Extraction, Quickblade Of Trembling Hands       3.530000
# 82      Nirvana                                         4.900000
# 75      Brutality Ivory Warmace                         2.420000
# 103     Singed Scalpel                                  4.350000
# 34      Retribution Axe                                 2.220000
# 37      Shadow Strike, Glory of Ending Hope             3.160000
#
#                                                                                    Total Purchase Value
# Item ID Item Name
# 92      Final Critic                                  <bound method Series.sum of 0      3.53\n1    ...
# 178     Oathbreaker, Last Hope of the Breaking Storm  <bound method Series.sum of 0      3.53\n1    ...
# 145     Fiery Glass Crusader                          <bound method Series.sum of 0      3.53\n1    ...
# 132     Persuasion                                    <bound method Series.sum of 0      3.53\n1    ...
# 108     Extraction, Quickblade Of Trembling Hands     <bound method Series.sum of 0      3.53\n1    ...
# 82      Nirvana                                       <bound method Series.sum of 0      3.53\n1    ...
# 75      Brutality Ivory Warmace                       <bound method Series.sum of 0      3.53\n1    ...
# 103     Singed Scalpel                                <bound method Series.sum of 0      3.53\n1    ...
# 34      Retribution Axe                               <bound method Series.sum of 0      3.53\n1    ...
# 37      Shadow Strike, Glory of Ending Hope           <bound method Series.sum of 0      3.53\n1    ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
most_profitable_items=popular_items.sort_values("Total Purchase value", ascending=False)
most_profitable_items.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-253-55df6ff4f4a6> in <module>
# ----> 1 most_profitable_items=popular_items.sort_values("Total Purchase value", ascending=False)
#       2 most_profitable_items.head(10)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5292
#    5293             by = by[0]
# -> 5294             k = self._get_label_or_level_values(by, axis=axis)
#    5295
#    5296             # need to rewrap column in Series to apply key function
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# -> 1563             raise KeyError(key)
#    1564
#    1565         # Check for duplicates
#
# KeyError: 'Total Purchase value'
